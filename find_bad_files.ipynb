# %%
from PIL import Image
import pandas as pd

# %%
bad_files = ['72255.jpg', '92899.jpg', '50420.jpg', '95347.jpg', '81823.jpg', '33557.jpg', 
             '98873.jpg','79499.jpg','95010.jpg','101947.jpg','41945.jpg']

# %%
df = pd.read_csv('train_all_classes.csv')
for index, row in df.loc[37524:].iterrows():
    print(index)
    if row['filename'] in bad_files:
        continue
    img_name = 'train/'+row['filename']
    print(img_name)
    image = Image.open(img_name).convert('RGB')
# Out:
# 37524
# train/74807.jpg
# 37525
# 37526
# train/84132.jpg
# 37527
# train/54602.jpg
# 37528
# train/87714.jpg
# 37529
# train/32245.jpg
# 37530
# train/84463.jpg
# 37531
# train/69776.jpg
# 37532
# train/47179.jpg
# 37533
# train/4459.jpg
# 37534
# train/50308.jpg
# 37535
# train/46133.jpg
# 37536
# train/55458.jpg
# 37537
# train/61102.jpg
# 37538
# train/68954.jpg
# 37539
# train/59328.jpg
# 37540
# train/56116.jpg
# 37541
# train/92578.jpg
# 37542
# train/5032.jpg
# 37543
# train/65830.jpg
# 37544
# train/1927.jpg
# 37545
# train/11434.jpg
# 37546
# train/60249.jpg
# 37547
# train/49263.jpg
# 37548
# train/79061.jpg
# 37549
# train/71344.jpg
# 37550
# train/81128.jpg
# 37551
# train/92441.jpg
# 37552
# train/54104.jpg
# 37553
# train/24688.jpg
# 37554
# train/26240.jpg
# 37555
# train/55629.jpg
# 37556
# train/20624.jpg
# 37557
# train/95643.jpg
# 37558
# train/10966.jpg
# 37559
# train/84176.jpg
# 37560
# train/66538.jpg
# 37561
# train/11740.jpg
# 37562
# train/55024.jpg
# ...
