# %%
import numpy as np
import matplotlib.pyplot as plt

resnet_train_acc = [0.3854, 0.4824, 0.5042, 0.5172, 0.5288]
resnet_val_acc = [0.4645, 0.4491, 0.4810, 0.4728, 0.4820]

alexnet_train_acc =  [0.4431, 0.5265, 0.5637, 0.6005, 0.6230]
alexnet_val_acc = [0.4902, 0.4645, 0.4933, 0.4779, 0.4933]

vgg_train_acc = [0.4358, 0.5054, 0.5198, 0.5236, 0.5357]
vgg_val_acc = [0.4995, 0.5200, 0.5211, 0.5313, 0.5396]

squeezenet_train_acc = [0.4124, 0.4815, 0.4993, 0.5259, 0.5321]
squeezenet_val_acc = [0.4460, 0.4748, 0.4728,  0.4892, 0.4861]

densenet_train_acc =  [0.4193, 0.5011, 0.5301, 0.5406, 0.5473]
densenet_val_acc = [0.4789, 0.4820, 0.4985, 0.4943, 0.5159]

inception_train_acc = [0.3497, 0.4316, 0.4572, 0.4706, 0.4781]
inception_val_acc = [0.4543, 0.4728, 0.4810, 0.4645,  0.4758]

plt.figure(1)
plt.plot(resnet_train_acc, label='resnet')
plt.plot(alexnet_train_acc, label='alexnet')
plt.plot(vgg_train_acc, label='vgg')
plt.plot(squeezenet_train_acc, label='squeezenet')
plt.plot(densenet_train_acc, label='deepnet')
plt.plot(inception_train_acc, label='inception')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.show()

plt.figure(2)
plt.plot(resnet_val_acc, label='resnet')
plt.plot(alexnet_val_acc, label='alexnet')
plt.plot(vgg_val_acc, label='vgg')
plt.plot(squeezenet_val_acc, label='squeezenet')
plt.plot(densenet_val_acc, label='deepnet')
plt.plot(inception_val_acc, label='inception')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.show()

plt.figure(3)
plt.plot(resnet_train_acc, label='training')
plt.plot(resnet_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Resnet Accuracy")
plt.legend()
plt.show()

plt.figure(4)
plt.plot(alexnet_train_acc, label='training')
plt.plot(alexnet_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Alexnet Accuracy")
plt.legend()
plt.show()

plt.figure(5)
plt.plot(vgg_train_acc, label='training')
plt.plot(vgg_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("VGG Accuracy")
plt.legend()
plt.show()

plt.figure(6)
plt.plot(squeezenet_train_acc, label='training')
plt.plot(squeezenet_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Squeezenet Accuracy")
plt.legend()
plt.show()

plt.figure(7)
plt.plot(densenet_train_acc, label='training')
plt.plot(densenet_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Densenet Accuracy")
plt.legend()
plt.show()

plt.figure(8)
plt.plot(inception_train_acc, label='training')
plt.plot(inception_val_acc, label='validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Inception Accuracy")
plt.legend()
plt.show()

# %%
densenet_feature_train_acc = [0.4447, 0.6090, 0.7298, 0.8542, 0.9363, 0.9808, 0.9917, 0.9966, 0.9982, 0.9989]
densenet_feature_val_acc = [0.5128, 0.5283, 0.5437, 0.5159, 0.5529, 0.5447, 0.5447, 0.5437, 0.5560, 0.5581]

vgg_feature_train_acc = [0.4465, 0.5704, 0.6532, 0.7330, 0.8243, 0.9015, 0.9402, 0.9706, 0.9770, 0.9869]
vgg_feature_val_acc = [0.5211, 0.5427, 0.5478, 0.5396, 0.5262, 0.5344, 0.5283, 0.5344, 0.5375, 0.5242]

densenet_train_acc10 = [0.4032, 0.4944, 0.5212, 0.5348, 0.5506, 0.5593, 0.5640, 0.5660, 0.5653, 0.5647]
densenet_val_acc10 = [0.4902, 0.4645, 0.4882, 0.5098, 0.5067, 0.5036, 0.5005, 0.4943, 0.5128, 0.4943]

vgg_train_acc10 = [0.4382, 0.5033, 0.5227, 0.5296, 0.5381, 0.5488, 0.5401, 0.5486, 0.5517, 0.5490]
vgg_val_acc10 = [0.4985, 0.5200, 0.5077, 0.5098, 0.5139, 0.5293, 0.5262, 0.5334, 0.5242, 0.5190]

plt.figure(9)
plt.plot(densenet_train_acc, label='Training Accuracy 5 Epochs')
plt.plot(densenet_val_acc, label='Validation Accuracy 5 Epochs')
plt.plot(densenet_train_acc10, label='Training Accuracy 10 Epochs')
plt.plot(densenet_val_acc10, label='Validation Accuracy 10 Epochs')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Densenet Accuracy Between Runs")
plt.legend()
plt.show()

plt.figure(10)
plt.plot(vgg_train_acc, label='Training Accuracy 5 Epochs')
plt.plot(vgg_val_acc, label='Validation Accuracy 5 Epochs')
plt.plot(vgg_train_acc10, label='Training Accuracy 10 Epochs')
plt.plot(vgg_val_acc10, label='Validation Accuracy 10 Epochs')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("VGG Accuracy Between Runs")
plt.legend()
plt.show()

plt.figure(11)
plt.plot(densenet_train_acc10, label='Training Accuracy')
plt.plot(densenet_val_acc10, label='Validation Accuracy')
plt.plot(densenet_feature_train_acc, label='Finetuned Training Accuracy')
plt.plot(densenet_feature_val_acc, label='Finetuned Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("10 Epoch Densenet Accuracy")
plt.legend()
plt.show()

plt.figure(12)
plt.plot(vgg_train_acc10, label='Training Accuracy')
plt.plot(vgg_val_acc10, label='Validation Accuracy')
plt.plot(vgg_feature_train_acc, label='Finetuned Training Accuracy')
plt.plot(vgg_feature_val_acc, label='Finetuned Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("10 Epoch VGG Accuracy")
plt.legend()
plt.show()

plt.figure(13)
plt.plot(vgg_train_acc10, label='VGG Training Accuracy')
plt.plot(vgg_val_acc10, label='VGG Validation Accuracy')
plt.plot(densenet_train_acc10, label='Densenet Training Accuracy')
plt.plot(densenet_val_acc10, label='Densenet Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("10 Epoch Accuracy")
plt.legend()
plt.show()

# %%
dense_train_30_acc = [0.4914, 0.5274, 0.5375, 0.5427, 0.5440, 0.5392, 0.5446, 0.5442, 0.5452]
dense_val_30_acc = [0.5538, 0.5606, 0.5432, 0.5496, 0.5606, 0.5570, 0.5542, 0.5556, 0.5506]

vgg_full_train_acc = [0.4951, 0.5116, 0.5206, 0.5193, 0.5249]
vgg_full_val_acc = [0.5425, 0.5496, 0.5710, 0.5540, 0.5570]

plt.figure(14)
plt.plot(vgg_train_acc, label='VGG Partial Training Accuracy')
plt.plot(vgg_val_acc, label='VGG Partial Validation Accuracy')
plt.plot(vgg_full_train_acc, label='VGG Full Training Accuracy')
plt.plot(vgg_full_val_acc, label='VGG Full Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("VGG Accuracy")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("predictions.csv")
num_classes = df.Labels.nunique()
confusion = np.zeros((num_classes, num_classes))
for _, r in df.iterrows():
    row = r.Labels
    col = r.Predictions
    confusion[row, col] += 1
print(confusion)
plt.imshow(confusion)
plt.colorbar(orientation='vertical')
plt.xlabel("Predicted classes")
plt.ylabel("True classes")
plt.title("Class Confusion Matrix")

print("Predicted Class Counts")
predicted = np.sum(confusion, axis=0)
print(predicted)

total = sum(predicted)

print("True Class Counts")
true = np.sum(confusion, axis=1)
print(true)


correct = 0
in1 = 0
in2 = 0
for i in range(num_classes):
    correct += confusion[i, i]
    s1 = max(0, i - 1)
    e1 = min(num_classes, i + 2)
    s2 = max(0, i - 2)
    e2 = min(num_classes, i + 3)
    in1 += np.sum(confusion[i, s1:e1])
    in2 += np.sum(confusion[i, s2:e2])
    
print("Percent Correct")
print(str((correct / total * 100)) + "%")

print("Percent Within 1 Classes")
print(str((in1 / total * 100)) + "%")

print("Percent Within 2 Classes")
print(str((in2 / total * 100)) + "%")
# Out:
# [[1069.  108.   85.   38.   19.]
#  [ 267.  631.  345.   34.   41.]
#  [ 134.  221.  633.  175.  174.]
#  [ 134.   75.  296.  398.  346.]
#  [  47.   18.  112.  106.  981.]]
# Predicted Class Counts
# [1651. 1053. 1471.  751. 1561.]
# True Class Counts
# [1319. 1318. 1337. 1249. 1264.]
# Percent Correct
# 57.22213658085401%
# Percent Within 1 Classes
# 85.95652844149838%
# Percent Within 2 Classes
# 95.42161245568059%

# %%
vgg_10class_train_acc = [0.3143, 0.3445, 0.3512, 0.3577, 0.3633]
vgg_10class_val_acc = [0.3616, 0.3873, 0.3903, 0.3847, 0.3977]

plt.figure(15)
plt.plot(vgg_10class_train_acc, label='VGG 10 Class Training Accuracy')
plt.plot(vgg_10class_val_acc, label='VGG 10 Class Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("VGG 10 Class Accuracy")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("predictions.csv")
num_classes = df.Labels.nunique()
confusion = np.zeros((num_classes, num_classes))
for _, r in df.iterrows():
    row = r.Labels
    col = r.Predictions
    confusion[row, col] += 1
print(confusion)
plt.imshow(confusion)
plt.colorbar(orientation='vertical')
plt.xlabel("Predicted classes")
plt.ylabel("True classes")
plt.title("Class Confusion Matrix")

print("Predicted Class Counts")
predicted = np.sum(confusion, axis=0)
print(predicted)

total = sum(predicted)

print("True Class Counts")
true = np.sum(confusion, axis=1)
print(true)


correct = 0
in1 = 0
in2 = 0
for i in range(num_classes):
    correct += confusion[i, i]
    s1 = max(0, i - 1)
    e1 = min(num_classes, i + 2)
    s2 = max(0, i - 2)
    e2 = min(num_classes, i + 3)
    in1 += np.sum(confusion[i, s1:e1])
    in2 += np.sum(confusion[i, s2:e2])
    
print("Percent Correct")
print(str((correct / total * 100)) + "%")

print("Percent Within 1 Classes")
print(str((in1 / total * 100)) + "%")

print("Percent Within 2 Classes")
print(str((in2 / total * 100)) + "%")

# %%
size = [0.03, 0.1, 0.3, 1]
train_loss = [1.1211, 1.0920, 1.1094, 1.1329]
val_loss = [1.5452, 1.2389, 1.1290, 1.1411]

plt.figure(16)
plt.loglog(size,train_loss ,label='Training Loss')
plt.loglog(size,val_loss, label='Validation Loss')
plt.xlabel("Proportion of the subset of data")
plt.ylabel("Loss")
plt.title("Loss vs Training Size After 5 epochs")
plt.legend()
plt.show()
